# %% [markdown]
# ## 🧠 AI Golf Caddie Thought Process
#
# ### 📌 Data Tracker
#
# - ✅ Decided to use **Blast Motion** for swing metrics like grip, tempo, swing speed, and face rotation.
# - ❌ Skipped Arccos Smart Sensors (~$200) — budget-friendly decision.
# - 🧾 Manually tracking other environmental and session-related data via a custom-built **Streamlit app** that saves to a CSV file for easy analysis and modeling later.
#
# ---
#
# ### 📋 Data I Plan to Track (via Streamlit form)
#
# #### 🏌️ Session Context
# 1. **Practice Type**
#    - Driving Range
#    - 9-Hole Course
#    - 18-Hole Course
#    - Custom (e.g. 3-Hole Course, Putt-Putt)
#
# 2. **Date and Time**
#    - Exact Date + Start/End Time
#
# 3. **Location**
#    - e.g., “TopGolf Charlotte,” “Pine Ridge Driving Range”
#
# 4. **Ball Used**
#    - (Optional — TBD if this matters)
#
# ---
#
# #### 🌦️ Weather & Environment (Manual Entry or API-Pulled Later)
# 6. **Average Temperature** (if session > 1hr)
# 7. **“Feels Like” Temperature**
# 8. **UV Index** (avg if >1hr)
# 9. **Wind Speed (MPH)**
# 10. **Wind Gusts (MPH)**
# 11. **Wind Direction**
# 12. **Humidity**
# 13. **Air Quality Index (AQI)**
#
# ---
#
# ### ✅ Why Track All This?
#
# - It allows my future AI model to understand not just *how* I swung, but *what* conditions influenced the shot.
# - I want to eventually predict or recommend club + swing adjustments based on *me* + the environment — not a generic model.
#
# ---
#
# ### ⏭️ Next Steps:
# - Build a Streamlit form with dropdowns, date/time pickers, and sliders.
# - Store results in a central CSV (`golf_data.csv`).
# - Eventually: Merge with Blast Motion CSV using timestamp or session tag.
#
#
# once I buy the blast motion, to show a couple of stats like average temp and average yardage with different clubs on the streamlit home page? But like merge the two csv files (one I do manually and one from blast motion)?
#
# PROBLEM!!!
# Blast Motion doesn't have data on how far the ball went but you can use an estimated formula of "Estimated Carry Distance (yards) ≈ Swing Speed (mph) × 2.3"
# But I also won't know the direction the ball went... thinking of adding a second manual csv that I can later hook together with the date column and then each indivual swing.
# Okay I am going to make that second csv
# I won't need the swing speed, tempo, yardage (unless I go to top golf) because the blast motion will track that and they will end up hooking together to know the full estimated data of the shot. I may take over 100 shots tho so maybe I can make another form in streamlit with a separate page/tab that asks for date and time for that entry, but then how would I track each golf swing.... like for instance if I go to top golf, ill use different clubs and each ball hit needs to have a specific direction and they need to be ordered to match the blast motion correctly.
# NEED a scalable way to log direction per shot
# is there a way to have the data and time be automatic instead of typing that in? Also maybe I can ask the user (haha me) for location and then automatically make the sessionID with that and then the date in the "topgolf0416" format. Then I can ask the user for an estimated time like three hours and it will automatically use that sessionID for three hours so I don't have to repediently type that in either.
# YES once we hit submit a text appears like "That was submitted" and then the boxes are cleared of data (but still saved in csv). Can we also start a timer on the top of the page to let the user know how long it will be logging that session id for? I also would love for the submit button and boxes being cleared to happen for the first form we created.
